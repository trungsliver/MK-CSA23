# %%
import pandas as pd

# %% [markdown]
# **Tải dữ liệu từ máy tính**

# %%
from google.colab import files
files.upload()    # Billionaires.csv
# Out:
#      <input type="file" id="files-992423cf-0b31-4dfd-87b8-69ed7078a335" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-992423cf-0b31-4dfd-87b8-69ed7078a335">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Đọc dữ liệu**

# %%
df = pd.read_csv('Billionaires.csv', index_col = 0)
df
# Out:
#                           Name Net Worth   Age Country | Territory  \
# Rank
# 1     Bernard Arnault & family    $211 B  74.0              France
# 2                    Elon Musk    $180 B  51.0       United States
# 3                   Jeff Bezos    $114 B  59.0       United States
# 4                Larry Ellison    $107 B  78.0       United States
# 5               Warren Buffett    $106 B  92.0       United States
# ...                        ...       ...   ...                 ...
# 2540                   Yu Rong      $1 B  51.0               China
# 2540    Richard Yuengling, Jr.      $1 B  80.0       United States
# 2540             Zhang Gongyun      $1 B  60.0               China
# 2540    Zhang Guiping & family      $1 B  71.0               China
# 2540               Inigo Zobel      $1 B  66.0         Philippines
#
#                             Source               Industry
# Rank
# 1                             LVMH       Fashion & Retail
# ...

# %% [markdown]
# **Check nhanh dữ liệu**

# %%
df.info()
# => hầu nhữ dữ liệu các cột là string, chưa so sánh phân tích được
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2640 entries, 1 to 2540
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 2640 non-null   object
#  1   Net Worth            2640 non-null   object
#  2   Age                  2576 non-null   float64
#  3   Country | Territory  2640 non-null   object
#  4   Source               2640 non-null   object
#  5   Industry             2640 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 144.4+ KB

# %% [markdown]
# # **Biến đổi dữ liệu**

# %% [markdown]
# **DataFrame.apply(): thay đổi giá trị 1 cột bằng hàm tự định nghĩa**

# %%
# Biển đổi dữ liệu Net Worth
def clean_networth(networth):
  # Xóa ký tự đầu và cuối: '$125B' => '125'
    return networth[1:-1]

df["Net Worth"] = df["Net Worth"].apply(clean_networth)
  # pd.to_numeric(<cột>): chuyển string => float
df["Net Worth"] = pd.to_numeric(df["Net Worth"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2640 entries, 1 to 2540
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 2640 non-null   object
#  1   Net Worth            2640 non-null   float64
#  2   Age                  2576 non-null   float64
#  3   Country | Territory  2640 non-null   object
#  4   Source               2640 non-null   object
#  5   Industry             2640 non-null   object
# dtypes: float64(2), object(4)
# memory usage: 144.4+ KB

# %%
# cách 2: Dùng lambda - hàm ẩn danh
df['Net worth'] = df['Net worth'].apply(lambda x: x[1:-1])
df["Net Worth"] = pd.to_numeric(df["Net Worth"])

# %%
# Biến đổi kiểu dữ liệu của age
df["Age"] = df["Age"].astype(int)
df.info()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_4043/2105876838.py in <cell line: 0>()
#       1 # Biến đổi kiểu dữ liệu của age
# ----> 2 df["Age"] = df["Age"].astype(int)
#       3 df.info()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
# ...

# %% [markdown]
# # **Nhóm và sắp xếp**

# %% [markdown]
# Đề bài: "Đưa ra tổng tài sản lớn nhất của các tỉ phú nằm ở lĩnh vực nào"
# <br>
# => Cần tính tổng lượng tài sản theo từng lĩnh vực

# %%
# Tính tổng tài sản (Net worth) theo lĩnh vực (Industry)
df_industry = df[['Industry', 'Net Worth']].groupby('Industry').sum()
df_industry
# Out:
#                             Net Worth
# Industry
# Automotive                      525.3
# Construction & Engineering      118.5
# Diversified                     905.2
# Energy                          453.5
# Fashion & Retail               1698.8
# Finance & Investments          1605.1
# Food & Beverage                 957.2
# Gambling & Casinos              120.5
# Healthcare                      643.2
# Logistics                       239.5
# Manufacturing                  1025.9
# Media & Entertainment           427.5
# Metals & Mining                 446.8
# Real Estate                     657.4
# Service                         173.4
# Sports                          134.5
# Technology                     1871.0
# Telecom                         203.5

# %% [markdown]
# Thao tác sắp xếp

# %%
# sắp xếp tăng dần
df_industry = df_industry.sort_values(by='Net Worth', ascending=False)
df_industry
# Out:
#                             Net Worth
# Industry
# Technology                     1871.0
# Fashion & Retail               1698.8
# Finance & Investments          1605.1
# Manufacturing                  1025.9
# Food & Beverage                 957.2
# Diversified                     905.2
# Real Estate                     657.4
# Healthcare                      643.2
# Automotive                      525.3
# Energy                          453.5
# Metals & Mining                 446.8
# Media & Entertainment           427.5
# Logistics                       239.5
# Telecom                         203.5
# Service                         173.4
# Sports                          134.5
# Gambling & Casinos              120.5
# Construction & Engineering      118.5

# %% [markdown]
# **Ví dụ 1: Tính tổng tài sản theo quốc gia**
# <br>
# **=> Top 5 quốc gia giàu nhất**

# %%
df_country = df[['Country | Territory', 'Net Worth']].groupby('Country | Territory').sum()
df_country = df_country.sort_values(by='Net Worth', ascending=False)
df_country.head(5)
# Out:
#                      Net Worth
# Country | Territory
# United States           4489.0
# China                   1644.7
# India                    674.8
# France                   590.0
# Germany                  585.4

# %% [markdown]
# **Ví dụ 2: Số lượng tỷ phú mỗi quốc gia**
# <br>
# **=> Quốc gia có nhiều tỷ phú nhất**

# %%
amount_billionaires = df[['Country | Territory', 'Name']].groupby('Country | Territory').count()
amount_billionaires = amount_billionaires.sort_values(by='Name', ascending=False)
amount_billionaires.head(1)
# Out:
#                      Name
# Country | Territory
# United States         734

# %% [markdown]
# # **Data Cleaning - Làm sạch dữ liệu**

# %%
from google.colab import files
files.upload()    # hockey_players_data.csv
# Out:
#      <input type="file" id="files-426cc3fa-01e0-43bb-97bb-fb2673b631dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-426cc3fa-01e0-43bb-97bb-fb2673b631dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('hockey_players_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   number        22 non-null     int64
#  1   name          22 non-null     object
#  2   position      22 non-null     object
#  3   games_played  22 non-null     int64
#  4   goals         12 non-null     float64
#  5   assists       22 non-null     int64
#  6   PIM           22 non-null     int64
#  7   birthdate     22 non-null     object
#  8   age           22 non-null     int64
#  9   birthplace    20 non-null     object
#  10  weight        11 non-null     float64
#  11  height        21 non-null     float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 2.2+ KB

# %%
df
# Out:
#     number                     name position  games_played  goals  assists  \
# 0       13      Mikyla Grant-Mentis        F             6    5.0        4
# 1       44         Lindsay Eastwood        D             6    4.0        5
# 2        2             Taylor Woods        F             6    4.0        4
# 3       19           Brooke Boquist        F             6    2.0        2
# 4       67               Emma Woods        F             6    NaN        4
# 5       21   Breanne Wilson-Bennett        F             6    2.0        4
# 6       27               Amy Curlew        F             6    NaN        2
# 7       27  Sarah-Eve Coutu-Godbout        F             6    2.0        4
# 8       18         Taytum Clairmont        F             6    1.0        3
# 9       18         Taytum Clairmont        F             6    1.0        3
# 10      27        Shiann Darkangelo        F             6    NaN        3
# ...

# %%
# Đếm các giá trị bị thiếu
df.isnull().sum()
# Out:
# number           0
# name             0
# position         0
# games_played     0
# goals           10
# assists          0
# PIM              0
# birthdate        0
# age              0
# birthplace       2
# weight          11
# height           1
# dtype: int64

# %% [markdown]
# dropna(): bỏ tất cả các hàng có giá trị bị khuyết: df.dropna()
# <br>
# Nếu muốn bỏ cột, thì kết hợp với axis=1: df.dropna(axis=1)

# %%
# Loại bỏ 1 số cột không cần thiết: 'birthdate', 'birthplace'
df.drop(['birthdate', 'birthplace'], axis=1, inplace=True)
df
# Out:
#     number                     name position  games_played  goals  assists  \
# 0       13      Mikyla Grant-Mentis        F             6    5.0        4
# 1       44         Lindsay Eastwood        D             6    4.0        5
# 2        2             Taylor Woods        F             6    4.0        4
# 3       19           Brooke Boquist        F             6    2.0        2
# 4       67               Emma Woods        F             6    NaN        4
# 5       21   Breanne Wilson-Bennett        F             6    2.0        4
# 6       27               Amy Curlew        F             6    NaN        2
# 7       27  Sarah-Eve Coutu-Godbout        F             6    2.0        4
# 8       18         Taytum Clairmont        F             6    1.0        3
# 9       18         Taytum Clairmont        F             6    1.0        3
# 10      27        Shiann Darkangelo        F             6    NaN        3
# ...

# %% [markdown]
# fillna(): thay thế các giá trị NaN thành giá trị mặc định

# %%
# Thay thế giá trị NaN thành 0 trong cột goals
df.goals = df.goals.fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   number        22 non-null     int64
#  1   name          22 non-null     object
#  2   position      22 non-null     object
#  3   games_played  22 non-null     int64
#  4   goals         22 non-null     float64
#  5   assists       22 non-null     int64
#  6   PIM           22 non-null     int64
#  7   age           22 non-null     int64
#  8   weight        11 non-null     float64
#  9   height        21 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 1.8+ KB

# %% [markdown]
# Kiểm tra dữ liệu lặp

# %%
# Đếm số dòng trùng nhau
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
# Xóa các dòng trùng nhau
df.drop_duplicates()
# Out:
#     number                     name position  games_played  goals  assists  \
# 0       13      Mikyla Grant-Mentis        F             6    5.0        4
# 1       44         Lindsay Eastwood        D             6    4.0        5
# 2        2             Taylor Woods        F             6    4.0        4
# 3       19           Brooke Boquist        F             6    2.0        2
# 4       67               Emma Woods        F             6    0.0        4
# 5       21   Breanne Wilson-Bennett        F             6    2.0        4
# 6       27               Amy Curlew        F             6    0.0        2
# 7       27  Sarah-Eve Coutu-Godbout        F             6    2.0        4
# 8       18         Taytum Clairmont        F             6    1.0        3
# 10      27        Shiann Darkangelo        F             6    0.0        3
# 11       7        Mackenzie MacNeil        F             6    2.0        1
# ...

# %% [markdown]
# Xử lý kiểu dữ liệu

# %%
# Chuyển age: float => int
df.age = df.age.astype("int")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   number        22 non-null     int64
#  1   name          22 non-null     object
#  2   position      22 non-null     object
#  3   games_played  22 non-null     int64
#  4   goals         22 non-null     float64
#  5   assists       22 non-null     int64
#  6   PIM           22 non-null     int64
#  7   age           22 non-null     int64
#  8   weight        11 non-null     float64
#  9   height        21 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 1.8+ KB

# %% [markdown]
# Kiểm tra dữ liệu có điều kiện

# %%
# Loại bỏ chiều cao, cân nặng âm
df = df[df["weight"] > 0]
df = df[df["height"] > 0]
df
# Out:
#     number              name position  games_played  goals  assists  PIM  age  \
# 2        2      Taylor Woods        F             6    4.0        4    4   26
# 4       67        Emma Woods        F             6    0.0        4    0   24
# 8       18  Taytum Clairmont        F             6    1.0        3   21   26
# 9       18  Taytum Clairmont        F             6    1.0        3   21   26
# 13       4      Sarah Steele        D             6    1.0        4    4   25
# 14      23       Megan Quinn        D             6    1.0        0    0   22
# 15      25        Emma Greco        D             6    0.0        0    0   22
# 16      15  Natalie Marcuzzi        F             6    0.0        0    0   27
# 17      91   Jenna McParland        F             6    0.0        0    0   33
# 18      91   Henna McParland        M             5    0.0        0    0   33
# 20      29       Julie Allen        F             6    0.0        0    0   26
#
#     weight  height
# ...

# %% [markdown]
# Chuẩn hóa dữ liệu dạng text

# %%
# Viết thường tất cả tên
df['name'] = df['name'].str.lower().str.strip()
df
# Out:
#     number              name position  games_played  goals  assists  PIM  age  \
# 2        2      taylor woods        F             6    4.0        4    4   26
# 4       67        emma woods        F             6    0.0        4    0   24
# 8       18  taytum clairmont        F             6    1.0        3   21   26
# 9       18  taytum clairmont        F             6    1.0        3   21   26
# 13       4      sarah steele        D             6    1.0        4    4   25
# 14      23       megan quinn        D             6    1.0        0    0   22
# 15      25        emma greco        D             6    0.0        0    0   22
# 16      15  natalie marcuzzi        F             6    0.0        0    0   27
# 17      91   jenna mcparland        F             6    0.0        0    0   33
# 18      91   henna mcparland        M             5    0.0        0    0   33
# 20      29       julie allen        F             6    0.0        0    0   26
#
#     weight  height
# ...

# %% [markdown]
# **Bài tập**
# - Top 3 cầu thủ có nhiều goals nhất
# - Chiều cao trung bình của các cầu thủ
# - Cầu thủ có cân nặng nhẹ nhất
# - Cầu thủ lớn tuổi nhất và trẻ nhất
# - Số lượng cầu thủ theo từng vị trí

# %%
df = pd.read_csv('hockey_players_data.csv')

# Top 3 cầu thủ có nhiều bàn thắng nhất
top3_goals = df[['name', 'goals']].sort_values(by='goals', ascending=False)
print(top3_goals.head(3))

# Chiều cao trung bình
avg_height = df["height"].mean()
print("Chiều cao trung bình:", avg_height)

# Cầu thủ cân nặng nhẹ nhất
min_weight = df["weight"].min()
lightest_player = df[df["weight"] == min_weight]
print(lightest_player[["name", "weight"]])

# Lớn tuổi nhất
oldest = df[df["age"] == df["age"].max()]
print("Cầu thủ lớn tuổi nhất:")
print(oldest[["name", "age"]])

# Trẻ nhất
youngest = df[df["age"] == df["age"].min()]
print("\nCầu thủ trẻ nhất:")
print(youngest[["name", "age"]])

# Số lượng cầu thủ theo vị trí
position_count = df["position"].value_counts()
print(position_count)
# Out:
#                   name  goals
# 0  Mikyla Grant-Mentis    5.0
# 1     Lindsay Eastwood    4.0
# 2         Taylor Woods    4.0
# Chiều cao trung bình: 5.072857142857142
#                 name  weight
# 16  Natalie Marcuzzi   135.0
# Cầu thủ lớn tuổi nhất:
#                name  age
# 17  Jenna McParland   33
# 18  Henna McParland   33
#
# Cầu thủ trẻ nhất:
#                    name  age
# 0   Mikyla Grant-Mentis   22
# 10    Shiann Darkangelo   22
# 14          Megan Quinn   22
# 15           Emma Greco   22
# position
# F    15
# D     5
# M     1
# G     1
# Name: count, dtype: int64
